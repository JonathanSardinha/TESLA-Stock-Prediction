# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
tesla = pd.read_csv('/content/tesla_new.csv')
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 2       1/7/2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 3       2/7/2010   23.000000   23.100000   18.709999         NaN   19.200001
# 4       6/7/2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2188   11/3/2019  283.519989  291.279999  280.500000  290.920013  290.920013
# 2189   12/3/2019  286.489990  288.070007  281.059998  283.359985  283.359985
# 2190  13-03-2019  283.899994  291.989990  282.700012  288.959991  288.959991
# 2191  14-03-2019  292.450012  295.390015  288.290009  289.959991  289.959991
# 2192  15-03-2019  283.510010  283.723999  274.399994  275.429993  275.429993
#
#           Volume
# 0     18766300.0
# ...

# %%
tesla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close      Volume
# 0  29-06-2010  19.000000  25.00  17.540001  23.889999  23.889999  18766300.0
# 1  30-06-2010  25.790001  30.42  23.299999  23.830000  23.830000  17187100.0
# 2    1/7/2010  25.000000  25.92  20.270000  21.959999  21.959999   8218800.0
# 3    2/7/2010  23.000000  23.10  18.709999        NaN  19.200001   5139800.0
# 4    6/7/2010  20.000000  20.00  15.830000  16.110001  16.110001         NaN

# %%
plt.figure(figsize=(8,6))
sns.set(style='whitegrid')
sns.distplot(tesla['Open'])
plt.title('Distribution of stock market opening',fontsize=20)
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(8,6))
sns.set(style='whitegrid')
sns.distplot(tesla['Close'])
plt.title('Distribution of Stock Market Closing',fontsize=20)
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(8,6))
sns.set(style='whitegrid')
sns.distplot(tesla['High'])
plt.title('Stock Market closed at HIGH',fontsize=20)
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(8,6))
sns.set(style='whitegrid')
sns.distplot(tesla['Low'])
plt.title('Stock Market closed at LOW',fontsize=20)
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='High',y='Low',hue='Open',data=tesla,s=40)
plt.title('High vs Low w.r.t Open Market',fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='High',y='Low',hue='Close',data=tesla,s=40)
plt.title('High vs Low w.r.t Close Market',fontsize=20)
plt.legend()
plt.show()

# %%
tesla=tesla.fillna(tesla.mean())
tesla
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#             Date        Open        High         Low       Close   Adj Close  \
# 0     29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 2       1/7/2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 3       2/7/2010   23.000000   23.100000   18.709999  175.786399   19.200001
# 4       6/7/2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2188   11/3/2019  283.519989  291.279999  280.500000  290.920013  290.920013
# ...

# %%
# Defining Predictor Variable

tesla['Open-Close'] = tesla.Open - tesla.Close
tesla['High-Low'] = tesla.High - tesla.Low

X = tesla[['Open-Close', 'High-Low']]
X.head()
# Out:
#    Open-Close  High-Low
# 0   -4.889999  7.459999
# 1    1.960001  7.120001
# 2    3.040001  5.650000
# 3 -152.786399  4.390001
# 4    3.889999  4.170000

# %%
# Defining Target Variable
# +1: Buy signal, -1: Sell signal
Y = np.where(tesla['Close'].shift(-1)>tesla['Close'],1,-1)

# %%
# Splitting the dataset in 70-30 ratio
split_percentage = 0.7
split = int(split_percentage*len(tesla))

X_train = X[:split]
Y_train = Y[:split]

X_test = X[split:]
Y_test = Y[split:]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Initiating KNN classifier
knn = KNeighborsClassifier(n_neighbors=15)

# fit the model
knn.fit(X_train,Y_train)

# Accuracy
accuracy_train = accuracy_score(Y_train, knn.predict(X_train))
accuracy_test = accuracy_score(Y_test, knn.predict(X_test))

print('Train_data accuracy: %2f' %accuracy_train)
print('Test_data accuracy: %2f' %accuracy_test)
# Out:
# Train_data accuracy: 0.604560
# Test_data accuracy: 0.463526

# %%
# Predicted Signal
tesla['Predicted Signal'] = knn.predict(X)

# SPY Cumulative returns
tesla['SPY_returns'] = np.log(tesla['Close']/tesla['Close'].shift(1))
Cumulative_SPY_returns = tesla[split:]['SPY_returns'].cumsum()*100

#Cumulative Strategy returns
tesla['Strategy_returns'] = tesla['SPY_returns']* tesla['Predicted Signal'].shift(1)
Cumulative_Strategy_returns = tesla[split:]['Strategy_returns'].cumsum()*100

#plotting results
plt.figure(figsize=(10,5))
plt.plot(Cumulative_SPY_returns,color='r',label='SPY Returns')
plt.plot(Cumulative_Strategy_returns,color='g',label='Strategy Returns')
plt.legend()
plt.show()
